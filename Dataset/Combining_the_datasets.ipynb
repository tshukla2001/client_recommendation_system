# %%
import pandas as pd
import random

fonts_df = pd.read_csv("./google_fonts.csv")

color_palettes_df = pd.read_csv("./color_palettes_dataset.csv")

descriptions = [
    "A modern tech startup website",
    "A vintage coffee shop menu",
    "A minimalist photography portfolio",
    "A vibrant fashion e-commerce site",
    "A cozy bookstore flyer",
    "A professional corporate business website",
    "A playful kids' educational app",
    "A bold and colorful travel blog",
    "A sleek and modern real estate brochure",
    "A retro-themed music festival poster",
    "A classic wedding invitation card",
    "An elegant jewelry store website",
    "A rustic organic farm brochure",
    "A futuristic AI tech conference poster",
    "A cheerful birthday party invitation",
    "A creative digital marketing agency site",
    "A luxury hotel booking website",
    "An eco-friendly product flyer",
    "A stylish personal fitness trainer website",
    "A tech gadgets review blog",
    "A traditional cultural festival flyer",
    "A vibrant summer camp poster",
    "An artistic photography gallery site",
    "A professional job portal website",
    "A funky online comic store",
    "A serene meditation app interface",
    "A sophisticated wine label design",
    "A dynamic sports event poster",
    "A cozy home decor catalog",
    "A trendy vegan food blog",
    "An adventurous outdoor travel website",
    "A creative ad agency portfolio",
    "A luxurious skincare product packaging",
    "A community event invitation flyer",
    "A futuristic car showroom website",
    "A high-energy fitness app",
    "A soothing spa and wellness site",
    "A chic fashion runway invite",
    "A rustic bakery menu",
    "A youthful gaming tournament poster",
    "An urban streetwear brand website",
    "A festive holiday season flyer",
    "A modern architect portfolio",
    "A colorful art supplies catalog",
    "An edgy tattoo studio website",
    "A vibrant floral shop brochure",
    "A tropical island vacation ad",
    "A historic museum exhibit poster",
    "A futuristic VR app interface",
    "An elegant minimalist resume template",
    "A motivational personal blog",
    "A trendy tech product landing page",
    "An educational coding bootcamp site",
    "A nostalgic retro diner menu",
    "A dynamic dance club flyer",
    "An inspiring book club brochure",
    "A clean and simple portfolio site",
    "A chic jewelry brand ad",
    "An artsy handmade crafts store flyer",
    "A refreshing juice brand website",
    "A youthful college festival poster",
    "A modern co-working space brochure",
    "A motivational fitness challenge invite",
    "A luxurious yacht rental website",
    "A playful toy store ad",
    "An elegant gala dinner invitation",
    "A quirky social media campaign poster",
    "A classic newspaper front page",
    "A bold automotive magazine cover",
    "An earthy gardening supply brochure",
    "A sleek digital product mockup site",
    "A rustic wine tasting event flyer",
    "A futuristic tech webinar invite",
    "An artistic mural exhibition poster",
    "A modern student portal website",
    "A minimalist interior design blog",
    "A vibrant community outreach flyer",
    "A classy personal chef menu",
    "An adventurous scuba diving ad",
    "A calming yoga retreat flyer",
    "A polished investment firm site",
    "A vintage postcard design",
    "A colorful children’s storybook cover",
    "A sleek urban car rental app",
    "A luxury perfume brand website",
    "A dynamic basketball game poster",
    "An elegant piano concert invitation",
    "A clean charity fundraising flyer",
    "A youthful online learning platform",
    "A vibrant indie music album cover",
    "An eco-friendly tech product ad",
    "A modern industrial design portfolio",
    "A stylish influencer’s personal site",
    "A rustic cabin rental ad",
    "A cheerful holiday gift catalog",
    "A bold energy drink branding page",
    "A serene nature photography blog",
    "A retro board game night invite",
    "An edgy rock concert poster",
    "A professional software agency site",
]

combined_data = []
for desc in descriptions:
    font = fonts_df.sample(1).iloc[0]['family']
    
    palette = color_palettes_df.sample(1).iloc[0]['colors']
    
    combined_data.append({
        "description": desc,
        "font": font,
        "color_palette": palette
    })

combined_df = pd.DataFrame(combined_data)

combined_df.to_csv("./combined_design_dataset.csv", index=False)
print("Combined dataset with realistic descriptions saved as combined_design_dataset_realistic.csv.")
# Out:
# Combined dataset with realistic descriptions saved as combined_design_dataset_realistic.csv.
